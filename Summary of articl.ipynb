# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
website = "https://uza.uz/uz/posts/ilon-mask-har-bir-uyni-elektr-stanciyaga-aylantirmoqchi_263478"

# %%
response = requests.get(website)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
text = soup.find("div", {"class": "content-block"}).get_text()

# %%
text
# Out:
# '\nТесла бош директори Илон Маск ҳар бир уйни компания маҳсулотларидан фойдаланган ҳолда, энергия ишлаб чиқарадиган, сақлайдиган ва қайта тармоққа етказиб берадиган, яъни электр тақсимлайдиган станцияга айлантирмоқчи.\nУшбу компания кўп йиллардан буён қуёш батареялари ва энергия захираларини сотиш билан шуғулланиб келади. Шу боис, компания қуёш энергияси захиралари маҳсулотлари билан биргаликда сотиш бўйича янги сиёсий коммунал хизматларни йўлга қўйиши мумкин.“Бу Тесла учун ҳам, коммунал хизматлар учун ҳам ривожланишнинг янгича омили ҳисобланади. Aгар мазкур стратегия бажарилмаса, коммунал хизматлар ўз мижозларига хизмат кўрсатишда оқсайди", – деган Маск. У ўтган ёзда Калифорнияда электр энергиясининг тез-тез тармоқдан узилганини ва бу жиддий муаммо эканини айтган.Компания ўз сиёсатини ўзгартирди. Энди мижозлар алоҳида қуёш батареяси ёки унинг "Powerwall" энергия йиғиш қурилмасини сотиб олмайди, бутун бир тизим харид қилинади. Илон Маск твиттердаги баёнотида қуёш энергияси фақат "Pow
# ...

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)

# %%
uz_stopwords = ["ташқарига",  "битта",  "билан",  "ўзи",  "тўрт",  "ҳеч бўлмаганда",  "ёнида",  "эллик",  "ҳар бири",  
                "бундан кейин",  "ёлғиз",  "тўла",  "орқага",  'нима бўлганда ҳам',  "мумкин",  "қаерда",  "сизники",  
                "қисм",  "олтмиш",  "бўш",  "биз",  "кимники",  "остида",  "бери",  "яхши",  "бундай",  'устида',  
                "бўладими",  "ҳеч қаерда",  "уч",  "ўртасида",  'чунки',  'на',  "олдин",  "юқори",  "кейин",  
                "аммо",  'Шахсий',  'лекин',  'кейингиси',  "бериш",  "ўн бир",  "саккиз",  "бу орада",  "тез-тез",  
                'нима бўлса ҳам',  "ҳар бир",  "икки",  "аллақачон",  "ташқари",  "кўринади",  "ўзингиз",  "керак",  
                "ҳеч қачон",  'бўларди',  "охирги",  'бўлиш',  'демоқ',  'давонида',  "бўлган",  'нима',  'қачон',  
                "бирга",  'Гарчи',  "ҳар хил",  'шунингдек',  "бошқалар",  "аксинча",  "ичида",  'қаерда',  'бироз',  
                "бошқа",  "булар",  "ўн",  'шундай',  'шунинг учун',  "ҳамма",  "собиқ",  "мен",  "ўша",  "ҳатто",  
                'У ерда',  "давомида",  'у',  'ёки',  "бу",  'кўпроқ',  "ҳар доим",  "улар",  'ким',  "унинг",  "кўрсатиш",  
                'бошқа жойда',  "ҳеч ким",  "ҳали",  "кўра",  "нима учун",  "ҳам",  "бўлмаса",  "қилинган",  "юқорида",  
                'уни',  "қўнғироқ",  "у эрдан",  "ҳамма нарса",  "бизники",  "орқали",  "шунга қарамай",  "томонга",  
                "ўзимиз",  "ён",  "кимдир",  "менинг",  "пастки",  "исм",  'ўн икки',  'бошқа',  "шу билан",  "орқада", 
                "қаерда",  "ўзлари",  'қайси',  "олиш",  'ҳақиқатдан ҳам',  'учун',  "жуда",  "олд",  "юз",  'илтимос',  
                "яна",  "бир жойда",  'ва',  "гарчи",  "устига",  "ҳамма жойда",  "кўп",  "ба'зида",  'бу',  "бўлиш",  
                'бир хил',  "деярли",  "бор эди",  "қандай",  "биринчи",  "асосан",  "бундан ташқари",  "қандайдир тарзда", 
                "эди",  'биз',  "айнан",  "йигирма",  'ҳолбуки',  "энг",  "атрофида",  'Камроқ',  "учинчи",  'Бу ерга',  
                "ҳозир",  "агар",  "ҳақиқатан ҳам",  "олдиндан",  "бўйлаб",  "меники",  'аввал',  'бир марта',  'ўн беш',  
                "шунчаки",  "ким",  "сизнинг",  "кўп",  "беш",  "қарши",  "фойдаланиш",  "ким бўлса",  "у эрда",  "қирқ",  
                "ташқарида",  "миқдори",  "жиддий",  "бизнинг",  "олти",  "ҳақида",  "балки",  "ҳолда",  "бўлди",  "устида",
                "барибир",  "қачондир",  "қадар",  "шунинг учун",  "етарли",  "туюларди",  "қўйиш",  "акс ҳолда",  "сен",  
                "пастда",  "кўпроқ",  "иккаласи",  "ўзим",  "ишлатилган",  "пастга",  "оз",  "бўлади",  "орасида",  "қаердан", 
                "ҳар қандай жойда",  "нимадур",  "уларнинг",  "ҳар ким",  "каби",  "юқорига",  "тўққиз",  "ичига",  "орасида", 
                "бутун",  "бир нечта",  "фақат",  "ҳеч ким",  "томонидан",  "ҳеч нарса",  "бу эрда",  "қандай",  "ҳар қандай"]

# %%
stopwords.append(uz_stopwords)

# %%
stopwords
# Out:
# ['whereafter',
#  'yourselves',
#  'twelve',
#  'had',
#  'formerly',
#  'few',
#  'name',
#  'quite',
#  'therein',
#  'hers',
#  'all',
#  'except',
#  'although',
#  'behind',
#  'hundred',
#  'made',
#  'within',
#  'often',
#  'already',
#  "'s",
#  'mine',
#  'what',
#  'at',
#  'sometimes',
#  'whence',
#  'between',
#  'this',
#  'done',
#  'become',
#  "'d",
#  'these',
#  'latter',
#  'move',
#  'itself',
#  'off',
#  'an',
#  'namely',
#  'along',
#  'until',
#  'former',
#  'least',
#  'been',
#  'perhaps',
#  '‘ve',
#  'even',
#  'via',
#  '’ve',
#  'cannot',
#  'give',
#  'she',
#  'about',
#  'whereby',
#  'themselves',
#  'in',
#  'out',
#  "'ve",
#  'front',
#  'just',
#  'for',
#  'somehow',
#  'we',
#  'why',
#  'noone',
#  'as',
#  'into',
#  'may',
#  'across',
#  'onto',
#  'when',
#  'toward',
#  'much',
#  'upon',
#  'make',
#  'never',
#  'whereas',
#  'get',
#  'anyone',
#  'he',
#  'per',
#  'doing',
#  'nine',
#  'whatever',
#  'otherwise',
#  'almost',
# ...

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['\n', 'Тесла', 'бош', 'директори', 'Илон', 'Маск', 'ҳар', 'бир', 'уйни', 'компания', 'маҳсулотларидан', 'фойдаланган', 'ҳолда', ',', 'энергия', 'ишлаб', 'чиқарадиган', ',', 'сақлайдиган', 'ва', 'қайта', 'тармоққа', 'етказиб', 'берадиган', ',', 'яъни', 'электр', 'тақсимлайдиган', 'станцияга', 'айлантирмоқчи', '.', '\n', 'Ушбу', 'компания', 'кўп', 'йиллардан', 'буён', 'қуёш', 'батареялари', 'ва', 'энергия', 'захираларини', 'сотиш', 'билан', 'шуғулланиб', 'келади', '.', 'Шу', 'боис', ',', 'компания', 'қуёш', 'энергияси', 'захиралари', 'маҳсулотлари', 'билан', 'биргаликда', 'сотиш', 'бўйича', 'янги', 'сиёсий', 'коммунал', 'хизматларни', 'йўлга', 'қўйиши', 'мумкин', '.', '“Бу', 'Тесла', 'учун', 'ҳам', ',', 'коммунал', 'хизматлар', 'учун', 'ҳам', 'ривожланишнинг', 'янгича', 'омили', 'ҳисобланади', '.', 'Aгар', 'мазкур', 'стратегия', 'бажарилмаса', ',', 'коммунал', 'хизматлар', 'ўз', 'мижозларига', 'хизмат', 'кўрсатишда', 'оқсайди', '"', ',', '–', 'деган', 'Маск', '.', 'У', 'ўтган', 'ёзда'
# ...

# %%
punctuation = punctuation + '\n' + '\n\n'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n\n\n'

# %%
word_frequencies = {}
for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation :
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

# %%
print(word_frequencies)
# Out:
# {'Тесла': 2, 'бош': 1, 'директори': 1, 'Илон': 3, 'Маск': 4, 'ҳар': 1, 'бир': 2, 'уйни': 2, 'компания': 3, 'маҳсулотларидан': 1, 'фойдаланган': 1, 'ҳолда': 1, 'энергия': 3, 'ишлаб': 1, 'чиқарадиган': 1, 'сақлайдиган': 1, 'ва': 6, 'қайта': 1, 'тармоққа': 1, 'етказиб': 1, 'берадиган': 1, 'яъни': 1, 'электр': 4, 'тақсимлайдиган': 1, 'станцияга': 1, 'айлантирмоқчи': 1, 'Ушбу': 2, 'кўп': 1, 'йиллардан': 1, 'буён': 1, 'қуёш': 4, 'батареялари': 1, 'захираларини': 1, 'сотиш': 2, 'билан': 4, 'шуғулланиб': 1, 'келади': 1, 'Шу': 1, 'боис': 1, 'энергияси': 3, 'захиралари': 1, 'маҳсулотлари': 1, 'биргаликда': 1, 'бўйича': 1, 'янги': 1, 'сиёсий': 1, 'коммунал': 3, 'хизматларни': 1, 'йўлга': 1, 'қўйиши': 1, 'мумкин': 2, '“Бу': 1, 'учун': 2, 'ҳам': 2, 'хизматлар': 2, 'ривожланишнинг': 1, 'янгича': 1, 'омили': 1, 'ҳисобланади': 1, 'Aгар': 1, 'мазкур': 1, 'стратегия': 1, 'бажарилмаса': 1, 'ўз': 2, 'мижозларига': 1, 'хизмат': 1, 'кўрсатишда': 1, 'оқсайди': 1, '–': 1, 'деган': 1, 'У': 1, 'ўтган': 1, 'ёз
# ...

# %%
max_frequency = max(word_frequencies.values())

# %%
max_frequency
# Out:
# 6

# %%
for  word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word] /max_frequency

# %%
print(word_frequencies)
# Out:
# {'Тесла': 0.3333333333333333, 'бош': 0.16666666666666666, 'директори': 0.16666666666666666, 'Илон': 0.5, 'Маск': 0.6666666666666666, 'ҳар': 0.16666666666666666, 'бир': 0.3333333333333333, 'уйни': 0.3333333333333333, 'компания': 0.5, 'маҳсулотларидан': 0.16666666666666666, 'фойдаланган': 0.16666666666666666, 'ҳолда': 0.16666666666666666, 'энергия': 0.5, 'ишлаб': 0.16666666666666666, 'чиқарадиган': 0.16666666666666666, 'сақлайдиган': 0.16666666666666666, 'ва': 1.0, 'қайта': 0.16666666666666666, 'тармоққа': 0.16666666666666666, 'етказиб': 0.16666666666666666, 'берадиган': 0.16666666666666666, 'яъни': 0.16666666666666666, 'электр': 0.6666666666666666, 'тақсимлайдиган': 0.16666666666666666, 'станцияга': 0.16666666666666666, 'айлантирмоқчи': 0.16666666666666666, 'Ушбу': 0.3333333333333333, 'кўп': 0.16666666666666666, 'йиллардан': 0.16666666666666666, 'буён': 0.16666666666666666, 'қуёш': 0.6666666666666666, 'батареялари': 0.16666666666666666, 'захираларини': 0.16666666666666666, 'сотиш': 0.
# ...

# %%
sentence_tokens = [sent for sent in doc.sents]

# %%
print(sentence_tokens)
# Out:
# [
# Тесла бош директори Илон Маск ҳар бир уйни компания маҳсулотларидан фойдаланган ҳолда, энергия ишлаб чиқарадиган, сақлайдиган ва қайта тармоққа етказиб берадиган, яъни электр тақсимлайдиган станцияга айлантирмоқчи.,
# ...

# %%
sentence_score = {}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_score.keys():
                sentence_score[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_score[sent] += word_frequencies[word.text.lower()]

# %%
sentence_score
# Out:
# {
#  Тесла бош директори Илон Маск ҳар бир уйни компания маҳсулотларидан фойдаланган ҳолда, энергия ишлаб чиқарадиган, сақлайдиган ва қайта тармоққа етказиб берадиган, яъни электр тақсимлайдиган станцияга айлантирмоқчи.: 6.166666666666669,
#
#  Ушбу компания кўп йиллардан буён қуёш батареялари ва энергия захираларини сотиш билан шуғулланиб келади.: 4.833333333333334,
#  Шу боис, компания қуёш энергияси захиралари маҳсулотлари билан биргаликда сотиш бўйича янги сиёсий коммунал хизматларни йўлга қўйиши мумкин.: 5.166666666666666,
#  “Бу Тесла учун ҳам, коммунал хизматлар учун ҳам ривожланишнинг янгича омили ҳисобланади.: 2.8333333333333326,
#  Aгар мазкур стратегия бажарилмаса, коммунал хизматлар ўз мижозларига хизмат кўрсатишда оқсайди", – деган Маск.: 2.666666666666666,
#  У ўтган ёзда Калифорнияда электр энергиясининг тез-тез тармоқдан узилганини ва бу жиддий муаммо эканини айтган.: 4.166666666666666,
#  Компания ўз сиёсатини ўзгартирди.: 1.1666666666666665,
# ...

# %%
from heapq import nlargest

# %%
select_length = int(len(sentence_tokens)*0.2)
select_length
# Out:
# 2

# %%
summary = nlargest(select_length, sentence_score, key=sentence_score.get)

# %%
summary
# Out:
# [
#  Тесла бош директори Илон Маск ҳар бир уйни компания маҳсулотларидан фойдаланган ҳолда, энергия ишлаб чиқарадиган, сақлайдиган ва қайта тармоққа етказиб берадиган, яъни электр тақсимлайдиган станцияга айлантирмоқчи.,
#  Шу боис, компания қуёш энергияси захиралари маҳсулотлари билан биргаликда сотиш бўйича янги сиёсий коммунал хизматларни йўлга қўйиши мумкин.]

# %%
final_summary = [word.text for word in summary]

# %%
summary = " ".join(final_summary)

# %%
print(summary)
# Out:
# Тесла бош директори Илон Маск ҳар бир уйни компания маҳсулотларидан фойдаланган ҳолда, энергия ишлаб чиқарадиган, сақлайдиган ва қайта тармоққа етказиб берадиган, яъни электр тақсимлайдиган станцияга айлантирмоқчи. Шу боис, компания қуёш энергияси захиралари маҳсулотлари билан биргаликда сотиш бўйича янги сиёсий коммунал хизматларни йўлга қўйиши мумкин.
